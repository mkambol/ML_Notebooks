# %% [markdown]
# <a href="https://colab.research.google.com/github/mkambol/ML_Notebooks/blob/master/AirQuality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import absolute_import, division, print_function

import pathlib

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from pathlib import Path

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers


zip_path = keras.utils.get_file("AirQualityUCI.zip", "https://archive.ics.uci.edu/ml/machine-learning-databases/00360/AirQualityUCI.zip", extract=True)
csv_path = Path(zip_path).parent.as_posix() + "/AirQualityUCI.csv"

# %%
air_quality = pd.read_csv(csv_path, sep=";")
#air_quality = air_quality.dropna()

air_quality
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# 5     10/03/2004  23.00.00    1,2       1197.0      38.0      4,7
# 6     11/03/2004  00.00.00    1,2       1185.0      31.0      3,6
# 7     11/03/2004  01.00.00      1       1136.0      31.0      3,3
# 8     11/03/2004  02.00.00    0,9       1094.0      24.0      2,3
# 9     11/03/2004  03.00.00    0,6       1010.0      19.0      1,7
# 10    11/03/2004  04.00.00   -200       1011.0      14.0      1,3
# 11    11/03/2004  05.00.00    0,7       1066.0       8.0      1,1
# 12    11/03/2004  06.00.00    0,7       1052.0      16.0      1,6
# ...
